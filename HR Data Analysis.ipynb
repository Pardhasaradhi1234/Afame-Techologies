# %% [markdown]
# # -----------------------------------     HR DATA ANALYSIS    ---------------------------------
# - Data cleansing involves removing unnecessary columns.
# - Giving the columns new names.
# - Eliminating redundant entries.
# - sanitizing specific columns.
# - Eliminate the dataset's NaN values.
# - Look for a few more changes if necessary

# %% [markdown]
# ### IMPORTING REQUIRED LIBRARIES

# %%
# importing Necessary libraires
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings("ignore")

# %%
# input the dataset and look through dataset
df = pd.read_csv("HR DATA.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ###### ""ATTRITION"" meaning employess leaving the company

# %%
# DATA CHECK
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# #### NO  NULL VALUES ARE TO BE SEEN IN DATASET BUT DIFF DATAYPES ARE PRESNT SO CATEGORIAL VALUES NEED TO BE HANDLED

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# #### In dataset the columns "EmployeeCount" and "StandardHours" have unique values and "std = o" so analysis doesnt required for this columns

# %%
# List all columns in the dataset
df.describe(include='O')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %% [markdown]
# #### "Over18" Column Has only one unique value so can be Ignored

# %%
#Checking for null values
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# #### -- NO NULL VALUES BUT LETS LOOK AT EXPLOTARY DATA ANLYSIS ON DIFFERENT COLUMNS WITH TARGET COLUMN

# %% [markdown]
# ## Explotary Data Analysis(EDA)
#
# #### Target Column "ATTRIRION"
# ##### - Catergoical columns

# %%
sns.countplot(x=df.Attrition)
plt.show()

# %% [markdown]
# #### More "NO" Values Than "Yes" its not an balanced data

# %%
#Impact of Business Travel o Attrition
sns.countplot(hue=df.Attrition,x=df.BusinessTravel)
plt.show()

# %% [markdown]
# #### Travelling is Rarerly Happening and More Perople are not satisfied with the job they are doing so more attrition in raraely travelling

# %%
#Impact of Department on Attrition
sns.countplot(hue=df.Attrition,x=df.Department)
plt.show()

# %% [markdown]
# #### Departments
# #### - Sales has medium rate of attrition
# #### - Reasearch and Development has High rate of attrition
# #### - Human Resources has Low rate of attrition

# %%
#Impact of EducationField on Attrition
sns.countplot(x=df.Attrition,hue =df.EducationField)
plt.show()

# %% [markdown]
# #### Life Sciences And Medical Field Education background have More no of employees than other education background and 100 employess are leaving in lifesciences less than 100 for other educationfield

# %%
#Impact of Gender on Attrition
sns.countplot(hue=df.Attrition,x=df.Gender)
plt.show()

# %% [markdown]
# #### Males are more compared to Females and males are to more number go out of the company

# %%
#Impact of OverTime on Attrition
sns.countplot(hue=df.Attrition,x=df.OverTime)
plt.show()

# %% [markdown]
# #### Employees who work over time have very rare difference from moving out of company than no overtime and overtime doesnt effect that much in attritioin

# %%
#Impact of JobRole on Attrition
plt.figure(figsize= (22,6.8),facecolor = 'white')
sns.countplot(hue=df.Attrition,x=df.JobRole)
plt.xlabel('JobRole',fontsize=10)
# Out:
# Text(0.5, 0, 'JobRole')

# %% [markdown]
# #### In human resources dept there is less attrition and in deptof laboratoty technician and sales executive have more members in it so they were tend to attrition

# %% [markdown]
# ## Anlalysis on Continues Data W.R.T to Target Coulmn

# %%
numerical_col = []
for column in df.columns:
    if df[column].dtype == "int64" and len(df[column].unique())>=10: #
        
        numerical_col.append(column)

# %%
#Displaying Coumns with Continuous Data 
numerical_col
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'EmployeeNumber',
#  'HourlyRate',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'TotalWorkingYears',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
df2=df[['Age',
 'DailyRate',
 'DistanceFromHome',
 'EmployeeNumber',
 'HourlyRate',
 'MonthlyIncome',
 'MonthlyRate',
 'NumCompaniesWorked',
 'PercentSalaryHike',
 'TotalWorkingYears',
 'YearsAtCompany',
 'YearsInCurrentRole',
 'YearsSinceLastPromotion',
 'YearsWithCurrManager']]

# %% [markdown]
# ## Another Method Of visualization using data 2
# ### - Graphical Representation

# %%
plt.figure(figsize=(20,25),facecolor = 'white')
plotnumber = 1

for column in df2:
    if plotnumber<=16:
        ax = plt.subplot(4,4,plotnumber)
        sns.histplot(x=df2[column].dropna(axis =0),hue=df.Attrition)
        plt.xlabel(column, fontsize=20)
        plt.ylabel("Attrition", fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ### Finding Inividual relation with attrition

# %% [markdown]
# - At the age of 20 - 35 their is more attrition
# - Higher the age low attrition is seen

# %%
# Impact of age on attrition
sns.histplot(hue=df.Attrition,x=df.Age)
plt.show()

# %%
#Impact of Home Dist on Attrition
sns.histplot(hue=df.Attrition,x=df.DistanceFromHome)
plt.show()

# %% [markdown]
# - More Near the distance  more tend to attrition and lesser distance less no of employess leaving the job

# %%
#Impact of MonthlyIncome on Attrition
sns.histplot(hue=df.Attrition,x=df.MonthlyIncome)
plt.show()

# %% [markdown]
# - people who have salary of 2500 are more to leave the company
# - higher the monthly income low amount of attrition

# %%
#Impact of NumCompaniesWorked on Attrition
sns.histplot(hue=df.Attrition,x=df2.NumCompaniesWorked)
plt.show()

# %% [markdown]
# - employee worked in 1 Company have more attrition the more comapies they worked the lesser amount attrition

# %%
#Impact of PercentSalaryHik on Attrition
sns.histplot(hue=df.Attrition,x=df2.PercentSalaryHike)
plt.show()

# %%
#Years at Company
sns.histplot(hue=df.Attrition,x=df2.TotalWorkingYears)
plt.show()

# %% [markdown]
# ## Analysis of Discrete Data on Target Column Attrition

# %%
discrete_col = []
for column in df.columns:
    if df[column].dtype == "int64" and len(df[column].unique())<=10: #
        
        discrete_col.append(column)
discrete_col
# Out:
# ['Education',
#  'EmployeeCount',
#  'EnvironmentSatisfaction',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'NumCompaniesWorked',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance']

# %%
df3 = df[['Education',
 'EmployeeCount',
 'EnvironmentSatisfaction',
 'JobInvolvement',
 'JobLevel',
 'JobSatisfaction',
 'NumCompaniesWorked',
 'PerformanceRating',
 'RelationshipSatisfaction',
 'StandardHours',
 'StockOptionLevel',
 'TrainingTimesLastYear',
 'WorkLifeBalance']]

# %% [markdown]
# ## Another Method Of visualization using data 3
# ### - Graphical Representation

# %%
plt.figure(figsize=(20,25),facecolor = 'white')
plotnumber = 1

for column in df3:
    if plotnumber<=16:
        ax = plt.subplot(4,4,plotnumber)
        sns.countplot(x=df3[column].dropna(axis =0),hue=df.Attrition)
        plt.xlabel(column, fontsize=20)
        plt.ylabel("Attrition", fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
#Impact of JobSatisfaction on Attrition
sns.countplot(hue=df.Attrition,x=df.EnvironmentSatisfaction)
plt.show()

# %% [markdown]
# - Increase in Job Environment gives Job satisfaction and No Attrition

# %%
#Impact of JobLevel on Attrition
sns.countplot(hue=df.Attrition,x=df.JobLevel)
plt.show()

# %% [markdown]
# - Lesser the Job level more attrition and Higher Job level less attrition

# %%
#Impact of JobInvovement on Attrition
sns.countplot(hue=df.Attrition,x=df.JobInvolvement)
plt.show()

# %% [markdown]
# - Who Have more JobInvovement i.e more job pressure so more attrition and somewhat lesser involvement tends to a smaller attrition

# %%
#Impact of StockOptionLevel on Attrition
sns.countplot(hue=df.Attrition,x=df.StockOptionLevel )
plt.show()

# %% [markdown]
# - Who have stock option are lesser to quit the job and

# %%
#Impact of PerformanceRating on Attrition
sns.countplot(hue=df.Attrition,x=df. PerformanceRating)
plt.show()

# %% [markdown]
# - People Who have less performancerate have more tend to leave the company an rartings are between 3-4 only and employees have moderately  peformed

# %% [markdown]
# ## Data Preprocessing and Cleaning

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# - NO NULL values so
# ### Categorical Data Handling

# %%
df.Attrition = df.Attrition.map({'Yes':1,'No':0})

# %%
df.BusinessTravel = df.BusinessTravel.map({'TravelFrequently':1,'TravelRarely':2,'Non-Travel':0})

# %%
df.Department = df.Department.map({'ResearchDevelopment':2,'Sales':1,'HumanResources':0})

# %%
df.EducationField = df.EducationField.map({'LifeSicences':5,'Medical':4,'Marketing':3,'TechnicalDegree':2,'Other':1,'HumanResources':0})

# %%
df.Gender = pd.get_dummies(df.Gender,drop_first = True)

# %%
df.JobRole = df.JobRole.map({'Laboratory Technician':8,'Sales Executive':7,'Research Scientist':6,'Sales Representative':5,'Human Resources':4,'Manufacturing Director':3,'HealthCare Representative':2,'Manager':1,'Research Director':0})

# %%
df.MartialStatus = df.MartialStatus.map({'Single':2,'Married':1,'Divorced':0})

# %%
df.OverTime= df.OverTime.map({'yes':1,'No':0})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 0 non-null      float64
#  2   BusinessTravel            150 non-null    float64
#  3   DailyRate                 1470 non-null   int64
#  4   Department                446 non-null    float64
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            705 non-null    float64
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   uint8
#  12  HourlyRate                1470 non-null   int64
# ...

# %% [markdown]
# ## FeatureSelection
# ### Eliminating Columns which have Unique Ones

# %%
df.drop({'Over18','EmployeeCount','EmployeeNumber','StandardHours'},axis=1,inplace=True)
